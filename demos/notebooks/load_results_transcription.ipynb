# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import gpitch.myplots as mplt
import numpy as np
import pickle
from gpitch import logistic

# %%
path = "/import/c4dm-04/alvarado/results/amt/transcription/"
fname = "MAPS_MUS-bach_846_AkPnBcht_transcription.p"

# %%
data = pickle.load(open(path + fname, "rb"))

# %%
plt.plot(logistic(data[0][0]))

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from gpitch.transcription_svi import AmtSvi
from gpitch.paths import path_train, path_test, path_load, path_save, test_fnames

# %%
fname = test_fnames[14]  # file to analyze
path = [path_train, path_test, path_load]  # paths to train and test data, learned kernels
frames = [88200, 2*44100]  # train and test number of frames

# %%
m = AmtSvi(test_fname=fname, frames=frames, path=path, gpu='0')
m.optimize(maxiter=np.infty, learning_rate=0.01)
# Out:
# analyzing file MAPS_MUS-grieg_zwerge_AkPnBcht.wav
# number of induncing variables: 63
# pitches to detect [38, 45, 62, 64, 65, 67, 69]

# %%
m.predict()

# %%
save_name = path_save + fname.strip(".wav") + "_model.p"                                                           
pickle.dump(obj=m,                                                                                                 
           file=open(save_name, "wb"))

# %%
m.plot()

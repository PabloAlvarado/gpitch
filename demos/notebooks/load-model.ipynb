# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from gpitch.transcription_svi import AmtSvi
import numpy as np
import gpitch
import pickle
from gpitch.paths import path_save, path_test

# %%
test_fnames = gpitch.load_filenames(directory=path_test,pattern="")

# %%
gpitch.init_settings('0');

# %%
fname = "/import/c4dm-04/alvarado/results/amt/transcription/"
model = pickle.load(open(fname + test_fnames[0].strip(".wav") + "_model.p", "rb"))

# %%
model.plot()

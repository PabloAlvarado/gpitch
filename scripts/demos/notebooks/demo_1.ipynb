# %% [markdown]
# # Toy example:
# In this notebook all model paremeters, i.e:  noise variance, lengthscale and variance of activation, all frequencies, variances and lenghscale of component, and variational distributions are learned simultaneously by maximazing the marginal likelihood.

# %%
# import jtplot module in notebook
from jupyterthemes import jtplot

# choose which theme to inherit plotting style from
# onedork | grade3 | oceans16 | chesterish | monokai | solarizedl | solarizedd
jtplot.style(theme='onedork')
jtplot.style(ticks=True, grid=False, figsize=(6, 4.5))

# %%
# %matplotlib inline
import sys 
sys.path.append('../../../')
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import gpflow, gpitch
reload(gpitch)
from gpitch.amtgp import logistic
from scipy.fftpack import fft, ifft, ifftshift
from scipy import signal
from gpitch import myplots

np.random.seed(20)
plt.rcParams['figure.figsize'] = (16, 3)  # set plot size

# %% [markdown]
# ## Generate synthetic data

# %%
# define hyperparameters for data generation
Nc = 10  # number of "harmoncics"
f0 = 220.0 # ideal natural frequency
N, fs = 1000, 16e3  # number of data points and sampling frequency
noise_var = 1e-3  # variance noise
x = np.linspace(0., (N-1.)/fs, N).reshape(-1, 1)  # time vector

# %% [markdown]
# Define kernels for component and activation

# %%
kern2 = gpflow.kernels.Matern32(input_dim=1, lengthscales=0.01, variance=10.)  # activation kernel

var = 0.25*np.random.rand(Nc)  # variances
var_scale = 1./ (4.*np.sum(var)) #rescale (sigma)
var *= var_scale  
leng = 0.09  # lengthscale
freq = f0*np.asarray(range(1, Nc+ 1)) + np.sqrt(100.)*np.random.randn(1)  # harmonic freqs with random deviation

kern1 = gpitch.kernels.MaternSpecMix(input_dim=1, lengthscales=leng, variances=var, 
                                     frequencies=freq, Nc=Nc) # component kernel

# %% [markdown]
# List of parameters of the kernels we used to generate the data.

# %%
#kern1  # kernel used for sample component

# %%
#kern2  # kernel used for sample activation

# %% [markdown]
# Compute covariance matrices, and sample one component and activation function

# %%
Kcom = kern1.compute_K_symm(x)  # cov matrices
Kact = kern2.compute_K_symm(x)
com = np.random.multivariate_normal(np.zeros((N)), Kcom, 1).reshape(-1, 1)  # sample component
com /= np.max(np.abs(com))
com -= com.mean()
g = np.random.multivariate_normal(np.zeros((N)), Kact, 1).reshape(-1, 1)  # sample activation
act = logistic(g)
act /= np.max(act)
y = act*com + np.sqrt(noise_var)*np.random.randn(N,1)  # generate noisy data

# %% [markdown]
# Plot data, activation and component

# %%
plt.figure(figsize=(16, 12))
plt.subplot(3,1,1), plt.title('data')
plt.plot(x, y, 'C0', lw=2 )

plt.subplot(3,1,2), plt.title('activation')
plt.plot(x, act, 'C1', lw=2)

plt.subplot(3,1,3), plt.title('component')
plt.plot(x, com, 'C2', lw=2)

# %% [markdown]
# ## Define model
# We take advantage of the information available in the Fourier transform of the data to initialize the component hyper-parameters, i.e. the frequency of each harmonic and its variance.

# %%
F_star, S_star, F, Y, S = gpitch.amtgp.init_com_params(y=y, fs=fs, Nh=Nc, ideal_f0=f0, scaled=True)  # get freqs and var 

plt.figure()
plt.plot(F, S/np.max(S))
plt.plot(F_star, S_star/np.max(S_star), 'xk', mew=2)
plt.legend(['Smoothed spectral density of data', 'location of harmonics found for initialization'])
plt.xlim([0, 8000])
# Out:
# (0, 8000)

# %% [markdown]
# Define kernels for component and activation, and generate model object ("sigmoid model")

# %%
kern_com = gpitch.kernels.MaternSpecMix(input_dim=1, lengthscales=0.05, variances=S_star, 
                                        frequencies=F_star, Nc=Nc)
kern_act = gpflow.kernels.Matern32(1)

# %%
dec = 160  # samples per window, decimation factor
z = np.vstack((x[::dec].copy(), x[-1].copy()))
m = gpitch.modgp.ModGP(x=x, y=y, z=z, kern_com=kern_com, kern_act=kern_act)  # sigmoid model

# %% [markdown]
# Set all parameters free to optimize, but variances of component

# %% [markdown]
# ## Inference
# Run optimizer several times to get a better visualization of parameters convergence, take the mean of the parameters results and optimize again. Finally, optimize variances of component kernel, as well as variational parameters.

# %%
m.optimize(disp=0, maxiter=500)
# Out:
#       fun: -758.5294923167927
#  hess_inv: <168x168 LbfgsInvHessProduct with dtype=float64>
#       jac: array([  1.92359255e+00,   1.41166666e-01,   2.35574244e-02,
#          1.36810975e-04,   1.75079903e-01,   3.72018633e-03,
#         -5.23696205e-01,   2.35972510e-04,  -1.89244497e+00,
#          5.82184235e-05,  -5.96963055e-04,   8.96486154e-01,
#         -1.38938668e-02,  -1.98795004e-01,   2.94808882e-02,
#          1.16645639e+00,   1.47260257e-02,   4.52826894e-01,
#          3.27706871e-03,  -2.81413437e-01,   1.46504723e-03,
#          1.65011261e-02,  -1.67221938e+00,   9.96111617e-01,
#         -3.33393461e+00,  -1.30529229e+00,  -5.68644743e-01,
#         -6.20083873e-01,  -9.85213960e-02,   5.19416508e-01,
#          6.38438700e-01,   3.05423960e-01,   6.48647414e-01,
#         -2.22718271e-02,   2.04333736e+00,  -7.52765827e-01,
#         -1.22457415e+00,  -7.55544599e-01,  -1.71918436e-01,
#         -1.44073791e-01,  -3.53034696e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -1.68519611e+00,  -7.24961179e-01,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -8.18617226e-01,
#         -3.18759224e-01,  -1.27642758e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -3.55221937e-01,  -1.69868579e+00,
#          8.08011134e-01,  -4.34062043e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -2.18405722e-01,  -3.27957159e+00,  -1.02204340e-01,
#         -7.42253663e-01,  -1.80567488e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -3.93016121e-01,
#         -3.75283384e+00,  -7.74532777e-01,   3.70906324e-01,
#         -2.27820441e+00,   1.87210089e-01,  -0.00000000e+00,
#         -0.00000000e+00,  -6.63822098e-02,  -1.13690021e+00,
#         -2.12709346e-01,   1.10511190e+00,  -7.35900758e-01,
#         -8.11962950e-01,  -3.36033807e+00,  -0.00000000e+00,
#         -2.17854609e-01,   3.19598555e-02,   4.22213671e-01,
#          5.00884429e-01,   1.79430370e-01,  -1.61501538e-01,
#          1.41052699e-01,   8.80178152e-01,   1.70615671e-01,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -2.55828146e-01,   3.86767483e-01,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#          7.36919872e-01,   2.32882647e-01,  -1.53441462e-01,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -3.60897268e-01,
#          4.55067914e-01,  -7.16340849e-02,  -4.36847808e-01,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,   4.21211078e-01,   4.04307529e-01,
#          2.19485290e-01,   6.13987053e-01,  -2.22581257e-02,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         
,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#         -3.43769966e-03,   2.03883694e-01,   1.00983811e-01,
#         -1.81528931e-01,  -6.74608817e-03,   2.59359325e-01,
#          0.00000000e+00,   0.00000000e+00,   1.15489944e-01,
#          7.98446461e-02,   1.25941066e-01,   1.76283021e-01,
#         -1.59155323e-01,  -3.57707134e-02,   3.12982976e-01,
#          0.00000000e+00,   1.33546338e-01,  -5.72090711e-02,
#         -7.76546296e-02,   3.19089241e-02,  -6.36366348e-02,
#         -4.28269337e-02,   5.62855805e-03,   2.65630004e-01])

# %% [markdown]
# List of learned hyperparameters

# %%
m.kern_com
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_com.frequency_1</td><td>[ 241.81931581]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_10</td><td>[ 2292.67426282]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_2</td><td>[ 444.42576373]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_3</td><td>[ 834.04759257]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_4</td><td>[ 890.84722074]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_5</td><td>[ 1313.87852649]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_6</td><td>[ 1549.94595817]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_7</td><td>[ 1571.88880007]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_8</td><td>[ 2003.91564174]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.frequency_9</td><td>[ 2215.8086454]</td><td>None</td><td>+ve</td></tr><tr><td>kern_com.lengthscales</td><td>[ 0.09994426]</td><td>None</td><td>[0.0, 0.1]</td></tr><tr><td>kern_com.variance_1</td><td>[ 0.00378611]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_10</td><td>[  7.63543322e-05]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_2</td><td>[ 0.11210058]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_3</td><td>[ 0.00019254]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_4</td><td>[ 0.15842396]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_5</td><td>[  1.42177430e-06]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_6</td><td>[ 0.10117216]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_7</td><td>[  3.21949104e-06]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_8</td><td>[  1.30181394e-05]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_9</td><td>[ 0.03512595]</td><td>None</td><td>[0.0, 0.25]</td></tr></table>

# %%
m.kern_act
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_act.lengthscales</td><td>[ 0.04605835]</td><td>None</td><td>+ve</td></tr><tr><td>kern_act.variance</td><td>[ 10.40618962]</td><td>None</td><td>+ve</td></tr></table>

# %%
print m.likelihood.variance
# Out:
# variance transform:+ve prior:None
# [ 0.01113007]

# %% [markdown]
# ## Results
# Compute prediction for component and activation, plot results

# %% [markdown]
# ### Plot prediction

# %%
mean_f, var_f, mean_g, var_g, x_plot  = m.predict_all(x)
myplots.plot_results(mean_f, var_f, mean_g, var_g, x_plot, y)
plt.subplot(3, 1, 2)
plt.twinx()
plt.plot(x_plot, act, '.k')
plt.subplot(3, 1, 3)
plt.twinx()
plt.plot(x_plot, com, '.k')
# Out:
# /home/paad/anaconda2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Plot learned kernel

# %%
x_eval = x.copy() 
k_plot_model = m.kern_com.compute_K(x_eval, np.asarray(0.).reshape(-1,1))
k_plot_sample = kern1.compute_K(x_eval, np.asarray(0.).reshape(-1,1))

plt.figure(figsize=(16, 4))
plt.plot(x_eval, k_plot_model, lw=2)

# %% [markdown]
# ### Compare spectral density of data and learned component kernel

# %%
N = x_eval.size
Yk1 = fft(k_plot_model.reshape(-1,)) #  FFT data
Sk1 =  2./N * np.abs(Yk1[0:N//2]) #  spectral density data

plt.figure(figsize=(16, 8))
plt.subplot(2, 1, 1)
plt.plot(F, S / np.max(np.abs(S)), lw=2)
plt.legend([' Spectral density data'])
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 8000])

plt.subplot(2, 1, 2)
plt.plot(F, Sk1 / np.max(np.abs(Sk1)), lw=2)
plt.legend([' Spectral density learned component kernel'])
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 8000])
# Out:
# (0, 8000)

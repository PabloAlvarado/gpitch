# %% [markdown]
# # Toy example:
# In this notebook all model paremeters, i.e:  noise variance, lengthscale and variance of activation, all frequencies, variances and lenghscale of component, and variational distributions are learned simultaneously by maximazing the marginal likelihood.

# %%
from jupyterthemes import jtplot
jtplot.style(theme='onedork')
jtplot.style(ticks=True, grid=False, figsize=(6, 4.5))

# %%
# %matplotlib inline
import sys 
sys.path.append('../../../')
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import gpflow, gpitch
reload(gpitch)
from gpitch.amtgp import logistic
from scipy.fftpack import fft, ifft, ifftshift
from scipy import signal
from gpitch import myplots

np.random.seed(456465)
plt.rcParams['figure.figsize'] = (16, 3)  # set plot size

# %% [markdown]
# ## Generate synthetic data

# %%
# define hyperparameters for data generation
Nc = 5  # number of "harmoncics"
f0 = 220.0 # ideal natural frequency
N, fs = 1600, 16e3  # number of data points and sampling frequency
noise_var = 1e-3  # variance noise
x = np.linspace(0., (N-1.)/fs, N).reshape(-1, 1)  # time vector

# %% [markdown]
# Define kernels for component and activation

# %%
var = np.random.rand(Nc)  # variances
var_scale = 1./ (4.*np.sum(var)) #rescale (sigma)
var *= var_scale  
leng = 0.75  # lengthscale
freq = f0*np.asarray(range(1, Nc+ 1)) + np.sqrt(100.)*np.random.randn(Nc)  # harm freqs 

kern1 = gpitch.kernels.MaternSpecMix(lengthscales=leng, variances=var, frequencies=freq, 
                                     Nc=Nc) # component kernel
kern2 = gpflow.kernels.Matern32(input_dim=1, lengthscales=0.03, variance=10.)  # act kernel

# %% [markdown]
# Compute covariance matrices, and sample one component and activation function

# %%
Kcom = kern1.compute_K_symm(x)  # cov matrices
Kact = kern2.compute_K_symm(x)
com = np.random.multivariate_normal(np.zeros((N)), Kcom, 1).reshape(-1, 1)  # sample component
com /= np.max(np.abs(com))
com -= com.mean()
g = np.random.multivariate_normal(np.zeros((N)), Kact, 1).reshape(-1, 1)  # sample activation
act = logistic(g)
act /= np.max(act)
y = act*com + np.sqrt(noise_var)*np.random.randn(N,1)  # generate noisy data

# %% [markdown]
# Plot data, activation and component

# %%
plt.figure(figsize=(16, 12))
plt.subplot(3,1,1), plt.title('data')
plt.plot(x, y, 'C0', lw=2 )

plt.subplot(3,1,2), plt.title('activation')
plt.plot(x, act, 'C1', lw=2)

plt.subplot(3,1,3), plt.title('component')
plt.plot(x, com, 'C2', lw=2)

# %% [markdown]
# ## Define model
# We take advantage of the information available in the Fourier transform of the data to initialize the component hyper-parameters, i.e. the frequency of each harmonic and its variance.

# %%
F_star, S_star, F, Y, S = gpitch.amtgp.init_com_params(y=y, fs=fs, Nh=Nc, ideal_f0=f0, scaled=True)  # get freqs and var 

plt.figure()
plt.plot(F, S/np.max(S))
plt.plot(F_star, S_star/np.max(S_star), 'xk', mew=2)
plt.legend(['Smoothed spectral density of data', 'location of harmonics found for initialization'])
plt.xlim([0, 8000])
# Out:
# (0, 8000)

# %% [markdown]
# Define kernels for component and activation, and generate model object ("sigmoid model")

# %%
kern_com = gpitch.kernels.MaternSpecMix(lengthscales=.1, variances=S_star,frequencies=F_star,
                                        Nc=Nc)
kern_act = gpflow.kernels.Matern32(1)

# %%
dec = 160  # samples per window, decimation factor
z = np.vstack((x[::dec].copy(), x[-1].copy()))
m = gpitch.modgp.ModGP(x=x, y=y, z=z, kern_com=kern_com, kern_act=kern_act)

# %% [markdown]
# Set all parameters free to optimize, but variances of component

# %%
m.kern_com.fixed = True
m.kern_com.lengthscales.fixed = False
m.kern_com.lengthscales.transform = gpflow.transforms.Logistic(0., 1.0)
m.kern_com.frequency_1.fixed = False
m.kern_com.frequency_2.fixed = False
m.kern_com.frequency_3.fixed = False
m.kern_com.frequency_4.fixed = False
m.kern_com.frequency_5.fixed = False
# m.kern_com.frequency_6.fixed = False
# m.kern_com.frequency_7.fixed = False
# m.kern_com.frequency_8.fixed = False
# m.kern_com.frequency_9.fixed = False
# m.kern_com.frequency_10.fixed = False
m.kern_act.fixed = False
m.likelihood.variance.fixed = False
m.z.fixed = True

# %% [markdown]
# ## Inference
# Run optimizer several times to get a better visualization of parameters convergence, take the mean of the parameters results and optimize again. Finally, optimize variances of component kernel, as well as variational parameters.

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern_act.lengthscales</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_act.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_1</td><td>[ 220.27534418]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_2</td><td>[ 450.56320401]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_3</td><td>[ 650.8135169]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_4</td><td>[ 871.08886108]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_5</td><td>[ 1121.40175219]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.lengthscales</td><td>[ 0.1]</td><td>None</td><td>[0.0, 1.0]</td></tr><tr><td>model.kern_com.variance_1</td><td>[ 0.11890592]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_2</td><td>[ 0.02240865]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_3</td><td>[ 0.00745749]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_4</td><td>[ 0.05940655]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_5</td><td>[ 0.0418214]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.likelihood.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.q_mu_act</td><td>[[ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]]</td><td>None</td><td>(none)</td></tr><tr><td>model.q_mu_com</td><td>[[ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]]</td><td>None</td><td>(none)</td></tr><tr><td>model.q_sqrt_act</td><td>[[[ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]]]</td><td>None</td><td>(none)</td></tr><tr><td>model.q_sqrt_com</td><td>[[[ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.]</br>  [ 1.]</br>  [ 0.]</br>  [ 0.]</br>  [ 0.] ...

# %%
maxiter, restarts = 1000, 3
#init_hyper, learnt_hyper, mse = m.optimize_restart(maxiter=maxiter, restarts=restarts)

# %%
#m.model.kern_act.lengthscales = learnt_hyper[0].mean().copy()
#m.model.kern_act.variance = learnt_hyper[1].mean().copy()
#m.model.likelihood.variance = learnt_hyper[2].mean().copy()
#m.model.kern_com.lengthscales = learnt_hyper[3].mean().copy()
m.optimize(disp=1, maxiter=maxiter)
# Out:
#       fun: -2428.2589115193855
#  hess_inv: <273x273 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ -1.23159692e+00,  -1.39427674e-01,   6.21686129e-01,
#         -1.34639821e-01,  -9.48361860e-03,   6.01165417e-02,
#         -9.61591596e-02,  -3.68107745e-02,  -2.12486605e-01,
#          1.69193002e+00,   8.87138819e-01,   6.75301883e-01,
#         -1.04133530e-01,  -5.50351206e-01,  -6.04363911e-01,
#         -1.48485970e-02,   5.25751713e-02,   3.39330429e-01,
#          2.22588314e-01,   9.37349424e-02,  -1.03709028e-01,
#         -2.16763426e-01,  -8.73202957e-02,  -3.36397376e-01,
#          1.34171486e-02,  -1.53609542e-01,   6.18630324e-02,
#          2.92681969e-03,  -1.03040939e-02,  -1.37294682e-01,
#         -2.07938192e-02,   2.38620854e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#          1.02973844e+00,   1.31837565e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,   9.57373026e-01,
#          1.35504282e+00,   2.08388608e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,   7.32722225e-01,   4.29819960e-01,
#          9.31018372e-01,   5.92234701e-01,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#          3.72155291e-01,  -4.24097443e-01,  -4.74367436e-01,
#         -4.01131871e-01,  -1.39864693e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,   3.74677213e-01,
#         -6.32173074e-01,  -1.01832154e+00,  -5.60214024e-01,
#         -4.32656541e-01,  -6.00432026e-03,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,   2.00931040e-01,  -7.15222815e-01,
#         -1.12015498e+00,  -3.68144145e-01,  -7.28679562e-02,
#          4.67431261e-01,   3.32730596e-01,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#          7.78406679e-02,  -6.20347075e-01,  -9.27266339e-01,
#         -1.94296325e-01,   2.64783699e-01,   3.12894276e-01,
#          1.59775130e-01,   4.15530605e-01,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,   1.24849491e-01,
#         -3.17169230e-01,  -2.87676687e-01,  -4.16682470e-03,
#          1.80772420e-01,  -2.96647618e-01,  -6.51672916e-02,
#          6.26048562e-02,   5.09192574e-01,  -0.00000000e+00,
#         -0.00000000e+00,   8.38119302e-02,  -1.09291560e-01,
#         -7.43917481e-02,   2.62396680e-02,   5.27950514e-02,
#         -1.86355400e-01,   1.09486679e-01,  -1.74296787e-01,
#         -5.89762909e-03,   3.03045933e-01,  -0.00000000e+00,
#          2.08194241e-02,  -2.84434477e-02,  -2.26194777e-02,
#          2.57650150e-03,   1.42481640e-02,  -4.77544585e-02,
#          4.55563203e-02,  -4.81845477e-02,   2.49845307e-04,
#          4.39294562e-02,   1.75013742e-01,  -1.78448110e-02,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -7.63956553e-02,  -6.67476888e-02,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -5.25388601e-02,  -3.12741525e-02,  -6.17505420e-02,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -1.71944203e-02,
#         -7.54052339e-02,  -2.83463651e-02,  -5.06130013e-03,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -2.47864062e-02,  -2.29602036e-02,
#          1.39709711e-02,  -7.34066147e-03,  -2.94683902e-02,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -1.46255693e-02,   8.47260135e-02,  -6.24144546e-02,
#         -3.93648523e-02,   2.79756448e-02,  -8.13398044e-02,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,   2.64058279e-03,
#          1.64827938e-01,   2.17089784e-02,  -2.38188629e-02,
#         -5.61172625e-02,   1.55365996e-02,  -1.83783896e-01,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,   5.70381448e-04,  -6.54435755e-02,
#          4.98707385e-02,  -1.33286197e-02,  -2.92822741e-02,
#         -4.97262030e-02,  -2.03301209e-03,   4.52523789e-02,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#          4.99378543e-02,  -1.39395983e-01,   9.69233270e-03,
#          1.94252620e-02,   3.45183542e-02,   2.33659182e-02,
#          8.49590982e-02,  -4.36257075e-02,   1.45310549e-01,
#         -0.00000000e+00,  -0.00000000e+00,  -4.80702476e-02,
#         -2.45484619e-02,  -2.07082887e-02,   3.51921932e-02,
#          2.75006814e-02,   8.86741908e-03,   8.43160913e-03,
#         -8.13737725e-03,  -3.94235508e-03,  -6.22923479e-03,
#         -0.00000000e+00,   1.52020151e-03,   6.04356532e-02,
#         -2.30727037e-02,   3.05976166e-03,   3.25669799e-03,
#          1.01635971e-02,   3.06021980e-02,  -2.30324272e-02,
#          2.77019901e-02,  -2.84779422e-03,  -4.85974030e-02])
#   message: 'STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT'
#      nfev: 1095
#       nit: 1001
#    status: 1
#   success: False
#         x: array([ -2.63812256e+00,   7.90014800e+00,   2.17209996e+02,
#          4.51011533e+02,   6.49051579e+02,   8.66144475e+02,
#          1.11962032e+03,   7.37394596e+00,  -6.07832294e+00,
#         -1.27570267e+00,   1.39274032e+00,  -2.24968101e+00,
#          3.16081128e+00,  -5.15853752e+00,   1.17016935e+00,
#          2.55587017e+00,  -2.44801899e+00,  -2.58833037e+00,
#          1.84033921e-01,   4.57273655e-01,   1.14931313e+01,
#          9.42413022e-02,   2.10830503e+00,  -1.42170685e+00,
#         -3.36705612e+00,   4.81588795e+00,  -3.68745575e-01,
#          3.69078748e+00,   1.74737346e-02,   7.61828121e-01,
#          9.29516553e-01,  -2.64506163e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          1.22425952e-01,   3.91726507e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,  -1.51800966e-01,
#         -9.65398896e-02,   5.53569210e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   6.09105050e-02,   6.45824160e-02,
#         -1.07485763e-01,   3.06110049e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#         -2.86466567e-02,  -2.49879232e-02,   8.29548191e-02,
#         -6.57684948e-02,   5.10692988e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   1.95741349e-02,
#          1.63816478e-02,  -5.06807832e-02,   5.76960977e-02,
#         -8.57391320e-02,   9.10860443e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -1.30846131e-02,  -1.14055587e-02,
#          3.30260489e-02,  -3.18062401e-02,   4.12501236e-02,
#         -1.68776073e-01,   4.74986827e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          5.68704306e-03,   5.18745173e-03,  -1.80419847e-02,
#          1.43313062e-02,  -4.97411815e-03,   1.13365300e-01,
#         -9.92595609e-02,   4.72133662e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,  -2.27315383e-03,
#         -4.56166786e-03,   9.19475078e-03,  -7.87370948e-03,
#          2.54852542e-03,  -5.74513529e-02,   9.07180413e-02,
#         -8.08975602e-02,   1.21257863e-01,   0.00000000e+00,
#          0.00000000e+00,   5.42152407e-03,   5.76093964e-04,
#         -8.63899587e-03,   8.51176743e-03,  -5.12754947e-04,
#          3.79860641e-02,  -6.80543107e-02,   3.14339583e-02,
#         -1.50266338e-01,   2.65842116e-01,   0.00000000e+00,
#         -1.59546919e-03,  -2.01345416e-03,   5.04662888e-03,
#         -6.58164123e-03,   7.01688873e-04,  -3.38372293e-02,
#          6.51583279e-02,  -3.04599278e-03,  -3.33202923e-02,
#         -3.89808932e-01,   5.39499028e-01,   1.41597492e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -8.39946609e-03,  -1.15558803e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          5.74730892e-02,   2.24199600e-02,   1.10709481e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   7.43771001e-02,
#         -5.11264049e-02,  -6.17718259e-03,   1.30535489e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   1.35372484e-01,  -6.68578530e-02,
#          8.28247754e-02,   4.91026113e-02,   1.61566587e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          1.99925078e-01,  -2.09439689e-01,   1.26919538e-01,
#          2.02157713e-01,   1.93355415e-01,   2.22052311e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,  -1.22146087e-01,
#         -7.20232343e-02,   1.23078087e-01,   4.20973974e-02,
#          1.50044402e-01,   1.49982498e-01,   2.58415498e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   8.61983906e-02,  -3.80815119e-02,
#          1.27686424e-01,   2.16456021e-01,   1.42781831e-01,
#          2.03320329e-01,   9.75258480e-02,   2.38468143e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#         -1.10010659e-01,  -8.00447773e-02,   7.37273953e-02,
#          8.99001853e-02,   2.12859133e-01,   1.70982862e-01,
#          2.20707996e-01,  -8.20015317e-03,   1.91498081e-01,
#          0.00000000e+00,   0.00000000e+00,  -4.16697439e-01,
#          1.59372269e-01,  -9.96063594e-03,  -1.66315485e-01,
#          3.20195045e-02,   1.32354355e-01,   3.14347626e-01,
#          9.54546562e-02,   8.39434907e-03,   2.70642179e-01,
#          0.00000000e+00,   2.03768466e-02,   2.36970789e-01,
#         -1.04155948e-01,   1.11156368e-01,  -1.90784095e-01,
#          8.35824331e-02,   9.33615306e-02,   3.36657624e-01,
#          7.45544718e-02,  -1.14622588e-01,   4.51762768e-01])

# %%
m.kern_com.fixed = True
m.kern_act.fixed = True
m.likelihood.variance.fixed = True
m.kern_com.variance_1.fixed = False
m.kern_com.variance_2.fixed = False
m.kern_com.variance_3.fixed = False
m.kern_com.variance_4.fixed = False
m.kern_com.variance_5.fixed = False
# m.kern_com.variance_6.fixed = False
# m.kern_com.variance_7.fixed = False
# m.kern_com.variance_8.fixed = False
# m.kern_com.variance_9.fixed = False
# m.kern_com.variance_10.fixed = False

m.optimize(disp=1, maxiter=10)
# Out:
#       fun: -2428.7700379025077
#  hess_inv: <269x269 LbfgsInvHessProduct with dtype=float64>
#       jac: array([  3.39697160e+00,  -7.61039277e+00,   5.50412878e+00,
#         -3.22623161e+00,   3.67145562e+00,   7.04963627e-01,
#          3.48168869e+00,   3.99568160e+00,   3.80379914e+00,
#          2.98530448e+00,   1.98873203e+00,   1.26784515e+00,
#         -8.15266010e-02,  -3.08358014e-02,   1.35449403e-01,
#          6.60986902e-02,   2.69979472e-01,   1.67696267e+00,
#         -3.16161037e+00,   1.64314996e+00,  -3.11306045e+00,
#         -1.76477239e-02,   1.77881962e-02,  -3.33365406e-01,
#          1.50291658e+00,  -8.91478512e-01,   3.90725989e-02,
#         -3.35326098e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -2.33406715e+00,
#         -3.76544832e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -1.43692269e+00,  -3.15701772e+00,
#          1.22304150e+01,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -1.09708538e+00,  -3.14256228e+00,   3.44784547e+00,
#          3.13982057e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -6.03647674e-01,
#         -2.42897428e+00,  -5.02228571e+00,   8.19792493e-01,
#          3.75714536e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -2.18749887e-01,  -1.69417905e+00,
#         -6.63051136e+00,   9.27615414e-02,   2.67219150e+00,
#          1.81801745e-02,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -1.70470645e-01,  -1.07570791e+00,  -5.17660685e+00,
#         -1.02918580e-01,   1.63361544e+00,   1.14233578e-01,
#          1.82426666e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -4.78583431e-02,
#         -2.93310378e-01,  -2.58842170e+00,  -2.87824536e-01,
#          4.47678939e-01,  -1.78406812e-02,   7.74536524e-01,
#         -1.22470167e-01,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,   7.41206041e-02,  -4.89858708e-02,
#         -4.19628156e-01,  -9.43977013e-02,  -5.10794268e-03,
#         -2.81671937e-01,   5.22860072e-02,  -2.34170745e-03,
#          8.40291848e-02,  -0.00000000e+00,  -0.00000000e+00,
#          6.00326323e-02,  -4.46033456e-02,  -1.01699446e-01,
#          5.41596042e-03,   1.58816795e-02,  -1.48949443e-01,
#          1.28894204e-01,  -1.67015990e-01,  -7.58143305e-02,
#          2.18862028e-01,  -0.00000000e+00,   1.53482309e-02,
#         -8.29081238e-03,  -2.42220787e-02,  -4.24288332e-03,
#         -5.77611828e-04,  -3.94963199e-02,   4.90614345e-02,
#         -4.69256372e-02,  -1.65260749e-02,   3.01711723e-02,
#          1.58555293e-01,   3.52583811e-02,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -1.83931653e-02,   7.12989374e-02,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -1.31148247e-02,
#         -2.59919263e-02,  -4.63290116e-02,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -7.37545047e-04,  -2.58539121e-02,
#          2.29499830e-02,  -4.86937151e-02,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -1.51987612e-01,  -6.74460062e-02,  -9.55361325e-02,
#          1.57318688e-03,  -1.07182531e-01,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,   1.13713690e-02,
#          4.75975246e-02,  -4.81205416e-03,  -4.00923211e-02,
#          5.55666152e-02,  -7.79299337e-02,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -0.00000000e+00,  -3.60665519e-02,   1.03939566e-01,
#         -4.08142770e-03,  -2.11075808e-02,  -4.88971692e-02,
#          1.81734299e-02,  -1.17793713e-01,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,  -0.00000000e+00,
#         -2.22573913e-02,  -3.85113896e-02,   1.30504456e-02,
#         -3.52598931e-02,  -3.80986097e-02,  -6.63915677e-02,
#          1.18057789e-02,  -1.74126328e-02,  -0.00000000e+00,
#         -0.00000000e+00,  -0.00000000e+00,   1.25061450e-01,
#         -7.53443639e-02,   4.18923499e-02,   4.76628410e-02,
#          2.56797758e-02,   3.33249282e-02,   1.23157226e-02,
#          3.79258724e-02,   1.89919494e-02,  -0.00000000e+00,
#         -0.00000000e+00,  -5.96179679e-02,  -2.59752093e-02,
#         -1.03021709e-02,   2.23301597e-02,   3.46278363e-02,
#          5.19468545e-03,   9.00381649e-03,  -3.22611769e-02,
#          2.03149706e-02,  -3.33903534e-02,  -0.00000000e+00,
#         -1.16701759e-03,   3.65370520e-02,  -1.99364124e-02,
#          6.50879437e-03,   9.50750018e-03,   1.22578102e-02,
#          2.35837228e-02,  -3.29637364e-02,   2.14759191e-02,
#          4.92614714e-03,  -8.17394458e-02])
#   message: 'STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT'
#      nfev: 16
#       nit: 11
#    status: 1
#   success: False
#         x: array([ -8.07943928e-02,  -2.34451586e+00,  -3.52600792e+00,
#         -1.15385710e+00,  -1.59648132e+00,  -1.27789666e+00,
#          1.39221382e+00,  -2.25104611e+00,   3.16117175e+00,
#         -5.15822806e+00,   1.16999358e+00,   2.55371675e+00,
#         -2.44879986e+00,  -2.58975087e+00,   1.82961305e-01,
#          4.56809678e-01,   1.14923723e+01,   9.73212797e-02,
#          2.11145253e+00,  -1.43379086e+00,  -3.35794761e+00,
#          4.81990659e+00,  -3.70313582e-01,   3.69023967e+00,
#          1.35194490e-02,   7.64779866e-01,   9.30862064e-01,
#         -2.66343278e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   1.23277519e-01,
#          4.00745639e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -1.52648977e-01,  -9.83087224e-02,
#          5.78049094e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          6.04495641e-02,   6.44440676e-02,  -1.07583009e-01,
#          3.09727604e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,  -2.82289106e-02,
#         -2.47773791e-02,   8.11880908e-02,  -6.56140727e-02,
#          5.28144616e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   1.94494748e-02,   1.62176319e-02,
#         -5.23480784e-02,   5.76722288e-02,  -8.62471020e-02,
#          9.21912099e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#         -1.28523939e-02,  -1.09493447e-02,   3.25775330e-02,
#         -3.22978414e-02,   4.04870125e-02,  -1.70077300e-01,
#          4.79020160e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   5.80608181e-03,
#          6.18684258e-03,  -1.71754223e-02,   1.40575704e-02,
#         -5.97904672e-03,   1.12439507e-01,  -9.91915747e-02,
#          4.67209167e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -2.82187288e-03,  -3.54591336e-03,
#          9.71171472e-03,  -8.08464784e-03,   1.98163391e-03,
#         -5.58294709e-02,   9.11986988e-02,  -8.09753904e-02,
#          1.19023332e-01,   0.00000000e+00,   0.00000000e+00,
#          5.01722560e-03,   1.00441511e-03,  -8.45715971e-03,
#          8.32931097e-03,  -7.13576453e-04,   3.89463547e-02,
#         -6.85944107e-02,   3.23811531e-02,  -1.50161038e-01,
#          2.64330498e-01,   0.00000000e+00,  -1.69704879e-03,
#         -1.90376929e-03,   5.10956724e-03,  -6.60572543e-03,
#          6.53567695e-04,  -3.35902214e-02,   6.49274840e-02,
#         -2.78345075e-03,  -3.33036247e-02,  -3.90026914e-01,
#          5.38594119e-01,   1.41617797e-01,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#         -8.01845994e-03,  -1.15347229e-01,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   5.77106693e-02,
#          2.25173422e-02,   1.11031694e-01,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   7.42283955e-02,  -5.07966928e-02,
#         -6.06348360e-03,   1.30456446e-01,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          1.35712504e-01,  -6.65188903e-02,   8.29866460e-02,
#          4.90247584e-02,   1.61828275e-01,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   2.00038466e-01,
#         -2.09980473e-01,   1.27156508e-01,   2.02391477e-01,
#          1.93235543e-01,   2.22546572e-01,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -1.22239733e-01,  -7.28267233e-02,
#          1.23065008e-01,   4.21578925e-02,   1.50309500e-01,
#          1.49913613e-01,   2.59429307e-01,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          8.62327175e-02,  -3.76742322e-02,   1.27448900e-01,
#          2.16606559e-01,   1.42883976e-01,   2.03578346e-01,
#          9.75000851e-02,   2.38429364e-01,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,  -1.10335461e-01,
#         -7.93896051e-02,   7.35740680e-02,   8.97993006e-02,
#          2.12700763e-01,   1.70807746e-01,   2.20304741e-01,
#         -8.08851363e-03,   1.91006137e-01,   0.00000000e+00,
#          0.00000000e+00,  -4.16393186e-01,   1.59489551e-01,
#         -9.86021495e-03,  -1.66495509e-01,   3.18847746e-02,
#          1.32326709e-01,   3.14271574e-01,   9.55179408e-02,
#          8.36350898e-03,   2.70763295e-01,   0.00000000e+00,
#          2.03775765e-02,   2.36668905e-01,  -1.04024806e-01,
#          1.11114213e-01,  -1.90791350e-01,   8.35316838e-02,
#          9.32152122e-02,   3.36771084e-01,   7.44133874e-02,
#         -1.14608537e-01,   4.52051316e-01])

# %% [markdown]
# List of learned hyperparameters

# %%
m.kern_com  # learned kernel for component
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_com.frequency_1</td><td>[ 217.2099966]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_2</td><td>[ 451.01153442]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_3</td><td>[ 649.05158011]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_4</td><td>[ 866.1444761]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_5</td><td>[ 1119.62031971]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.lengthscales</td><td>[ 0.99937301]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_1</td><td>[ 0.1199531]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_2</td><td>[ 0.02187567]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_3</td><td>[ 0.0071453]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_4</td><td>[ 0.05994632]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>kern_com.variance_5</td><td>[ 0.04211849]</td><td>None</td><td>[0.0, 0.25]</td></tr></table>

# %%
kern1 # kernel used for sample component
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unnamed.frequency_1</td><td>[ 217.58837748]</td><td>None</td><td>+ve</td></tr><tr><td>unnamed.frequency_2</td><td>[ 446.94404207]</td><td>None</td><td>+ve</td></tr><tr><td>unnamed.frequency_3</td><td>[ 647.76830651]</td><td>None</td><td>+ve</td></tr><tr><td>unnamed.frequency_4</td><td>[ 866.37425036]</td><td>None</td><td>+ve</td></tr><tr><td>unnamed.frequency_5</td><td>[ 1117.56809435]</td><td>None</td><td>+ve</td></tr><tr><td>unnamed.lengthscales</td><td>[ 0.75]</td><td>None</td><td>[0.0, 1.0]</td></tr><tr><td>unnamed.variance_1</td><td>[ 0.09224944]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>unnamed.variance_2</td><td>[ 0.00739058]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>unnamed.variance_3</td><td>[ 0.02527962]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>unnamed.variance_4</td><td>[ 0.06395948]</td><td>None</td><td>[0.0, 0.25]</td></tr><tr><td>unnamed.variance_5</td><td>[ 0.06112088]</td><td>None</td><td>[0.0, 0.25]</td></tr></table>

# %%
m.kern_act  # learned kernel for activation
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_act.lengthscales</td><td>[ 0.06905622]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_act.variance</td><td>[ 7.90051962]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
kern2 # kernel used for sample activation
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unnamed.lengthscales</td><td>[ 0.03]</td><td>None</td><td>+ve</td></tr><tr><td>unnamed.variance</td><td>[ 10.]</td><td>None</td><td>+ve</td></tr></table>

# %%
print m.likelihood.variance  # print noise
# Out:
# variance transform:+ve prior:None [FIXED]
# [ 0.00229039]

# %% [markdown]
# ## Results
# Compute prediction for component and activation, plot results

# %%
reload(myplots)
mean_f, var_f, mean_g, var_g, x_plot  = m.predict_all(x)
myplots.plot_results(mean_f, var_f, mean_g, var_g, x_plot, y, z)
plt.subplot(3, 1, 2)
plt.twinx()
plt.plot(x_plot, act, '.k')

plt.subplot(3, 1, 3)
plt.twinx()
plt.plot(x_plot, com, '.k')
# Out:
# /home/paad/anaconda2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Plot prediction

# %% [markdown]
# ### Plot learned kernel

# %%
x_eval = x.copy() 
k_plot_model = m.kern_com.compute_K(x_eval, np.asarray(0.).reshape(-1,1))
k_plot_sample = kern1.compute_K(x_eval, np.asarray(0.).reshape(-1,1))

plt.figure(figsize=(16, 4))
plt.plot(x_eval, k_plot_model, lw=2)
plt.xlim([0., 0.1])
# Out:
# (0.0, 0.1)

# %% [markdown]
# ### Compare spectral density of data and learned component kernel

# %%
N = x_eval.size
Yk1 = fft(k_plot_model.reshape(-1,)) #  FFT data
Sk1 =  2./N * np.abs(Yk1[0:N//2]) #  spectral density data

plt.figure(figsize=(16, 8))
plt.subplot(2, 1, 1)
plt.plot(F, S / np.max(np.abs(S)), lw=2)
plt.legend([' Spectral density data'])
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 8000])

plt.subplot(2, 1, 2)
plt.plot(F, Sk1 / np.max(np.abs(Sk1)), lw=2)
plt.legend([' Spectral density learned component kernel'])
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 8000])
# Out:
# (0, 8000)

# %% [markdown]
# # Example using audio from MAPS dataset:
# In this notebook all model paremeters, i.e:  noise variance, lengthscale and variance of activation, all frequencies, variances and lenghscale of component, and variational distributions are learned simultaneously by maximazing the marginal likelihood.

# %%
# %matplotlib inline
import sys 
sys.path.append('../../../../')
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import gpflow, gpitch
reload(gpitch)
from gpitch.amtgp import logistic
from scipy.fftpack import fft, ifft, ifftshift
from scipy import signal
import time
from gpitch import myplots
import soundfile


plt.rcParams['figure.figsize'] = (16, 5)  # set plot size

# %% [markdown]
# ## Import data

# %% [markdown]
# Load and plot data.

# %%
midi = '64'
filename = '../../../../../datasets/maps/' + midi + '_1-down.wav'
N = 16000 # number of data points to load
fs, y = gpitch.amtgp.wavread(filename, start=7000, N=N)
x = np.linspace(0, (N-1.)/fs, N).reshape(-1, 1)
plt.figure()
plt.title('data with pitch ' + midi)
plt.plot(x, y, lw=2)

# %% [markdown]
# ## Define model
# We take advantage of the information available in the Fourier transform of the data to initialize the component hyper-parameters, i.e. the frequency of each harmonic and its variance.

# %%
Nc = 10
ideal_f0 = gpitch.amtgp.midi2frec(int(midi))
F_star, S_star, F, Y, S = gpitch.amtgp.init_com_params(y=y, fs=fs, Nh=Nc, ideal_f0=ideal_f0, scaled=True)  # get freqs and var

# %%
plt.figure()
plt.plot(F, S/np.max(S))
plt.plot(F_star, S_star/np.max(S_star), 'xk', mew=2)
plt.legend(['Smoothed spectral density of data', 'location of harmonics found for initialization'])
plt.xlim([0, 8000])
# Out:
# (0, 8000)

# %% [markdown]
# Define kernels for component and activation, and generate model object ("sigmoid model")

# %%
kern_com = gpitch.kernels.MaternSpecMix(input_dim=1, lengthscales=0.1, variances=S_star, 
                                        frequencies=F_star, Nc=Nc)
kern_act = gpflow.kernels.Matern32(input_dim=1, lengthscales=1., variance=10.)

# %%
dec = 160  # samples per window, decimation factor
minibatch_size = 400
z = np.vstack((x[::dec].copy(), x[-1].copy()))
m = gpitch.modgp.ModGP(x=x, y=y, z=z, kern_com=kern_com, kern_act=kern_act, whiten=True,
                       minibatch_size=minibatch_size)

# %% [markdown]
# Set all parameters free to optimize, but variances of component

# %%
m.kern_com.fixed = True
m.kern_com.lengthscales.fixed = False
m.kern_com.lengthscales.transform = gpflow.transforms.Logistic(0., 1.0)
m.fixed_msmkern_params(freq=False, var=True)
m.kern_act.fixed = False
m.likelihood.variance.fixed = False
m.z.fixed = True

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern_act.lengthscales</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_act.variance</td><td>[ 10.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_1</td><td>[ 328.04100513]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_10</td><td>[ 3352.41905238]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_2</td><td>[ 656.08201025]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_3</td><td>[ 985.12314039]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_4</td><td>[ 1316.16452057]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_5</td><td>[ 1648.20602575]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_6</td><td>[ 1983.24790599]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_7</td><td>[ 2319.28991124]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_8</td><td>[ 2660.33254157]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_9</td><td>[ 3004.37554694]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.lengthscales</td><td>[ 0.1]</td><td>None</td><td>[0.0, 1.0]</td></tr><tr><td>model.kern_com.variance_1</td><td>[ 0.09807212]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_10</td><td>[ 0.00211973]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_2</td><td>[ 0.03746632]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_3</td><td>[ 0.01526182]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_4</td><td>[ 0.01304943]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_5</td><td>[ 0.03379636]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_6</td><td>[ 0.01936641]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_7</td><td>[ 0.00860698]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_8</td><td>[ 0.00653013]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_9</td><td>[ 0.0157307]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.likelihood.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.q_mu_act</td><td>[[ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]]</td><td>None</td><td>(none)</td></tr><tr><td>model.q_mu_com</td><td>[[ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [  ...

# %% [markdown]
# ## Inference

# %%
st = time.time()
logt = []
logx = []
logf = []
def logger(x):
    if (logger.i % 10) == 0:
        logx.append(x)
        logf.append(m._objective(x)[0])
        logt.append(time.time() - st)
    logger.i+=1
logger.i = 1
m.x.minibatch_size = minibatch_size
m.y.minibatch_size = minibatch_size

# %%
maxiter = 5000
m.optimize(method=tf.train.AdamOptimizer(learning_rate=0.005), maxiter=maxiter, 
           callback=logger)
# Out:
# Caught KeyboardInterrupt, setting model                  with most recent state.

# %% [markdown]
# List of learned hyperparameters

# %%
plt.figure(figsize=(6, 4))
plt.plot(-np.array(logf))
plt.xlabel('iteration')
plt.ylabel('ELBO')
# Out:
# Text(0,0.5,u'ELBO')

# %%
mean_f, var_f, mean_g, var_g, x_plot  = m.predict_all(x)

# %%
xlim = [0.0, 1.0]
myplots.plot_results(mean_f, var_f, mean_g, var_g, x_plot, y, z, xlim)

# %%
print('The ideal natural frequency is ' + str(ideal_f0) + 'Hz')
# Out:
# The ideal natural frequency is 329.627556913Hz

# %%
m
#print ideal_f0
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern_act.lengthscales</td><td>[ 0.28004096]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_act.variance</td><td>[ 12.33553331]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_1</td><td>[ 327.62225993]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_10</td><td>[ 3353.10129306]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_2</td><td>[ 655.50034968]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_3</td><td>[ 984.5666595]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_4</td><td>[ 1318.17716034]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_5</td><td>[ 1647.57177225]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_6</td><td>[ 1982.06751518]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_7</td><td>[ 2318.83156125]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_8</td><td>[ 2659.44517779]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_9</td><td>[ 3003.40195417]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.lengthscales</td><td>[ 0.99740045]</td><td>None</td><td>[0.0, 1.0]</td></tr><tr><td>model.kern_com.variance_1</td><td>[ 0.09807212]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_10</td><td>[ 0.00211973]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_2</td><td>[ 0.03746632]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_3</td><td>[ 0.01526182]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_4</td><td>[ 0.01304943]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_5</td><td>[ 0.03379636]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_6</td><td>[ 0.01936641]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_7</td><td>[ 0.00860698]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_8</td><td>[ 0.00653013]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_9</td><td>[ 0.0157307]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.00113942]</td><td>None</td><td>+ve</td></tr><tr><td>model.q_mu_act</td><td>[[-2.01255818]</br> [-0.84877036]</br> [-0.76285997]</br> [-0.68375616]</br> [-0.60537199]</br> [-0.52646752]</br> [-0.44672364]</br> [-0.36573732]</br> [-0.2831935 ]</br> [-0.1988772 ]</br> [-0.11264473]</br> [-0.02416019]</br> [ 0.0668028 ]</br> [ 0.16043909]</br> [ 0.25711845]</br> [ 0.35703894]</br> [ 0.46026904]</br> [ 0.56675142]</br> [ 0.67568902]</br> [ 0.78610098]</br> [ 0.89605698]</br> [ 1.00224943]</br> [ 1.09870518]</br> [ 1.17296941]</br> [ 1.1983014 ]</br> [ 1.10861981]</br> [ 0.74302944]</br> [-0.36159374]</br> [-2.07257924]</br> [-2.3840683 ]</br> [-1.78261452]</br> [-0.73302026]</br> [ 0.107138  ]</br> [ 0.08945798]</br> [ 0.02628521]</br> [ 0.07918771]</br> [-0.04593672]</br> [-0.23419831]</br> [-0.25718762]</br> [-0.10616196]</br> [-0.1001052 ]</br> [-0.17174748]</br> [-0.16380291]</br> [-0.08857831]</br> [-0.08744531]</br> [-0.07612469]</br> [-0.05854365]</br> [-0.06644844]</br> [-0.11380562]</br> [-0.16411518]</br> [-0.15876038]</br> [-0.12832689]</br> [-0.11618358]</br> [-0.14651638]</br> [-0.16787032]</br> [-0.12974137]</br> [-0.08412792]</br> [-0.08658687]</br> [-0.09441541]</br> [-0.10942935]</br> [-0.133199  ]</br> [-0.15277659]</br> [-0.14889202]</br> [-0.14302134]</br> [-0.15499132]</br> [-0.14606976]</br> [-0.13165038]</br> [-0.11683487]</br> [-0.13535288]</br> [-0.19584454]</br> [-0.19660171]</br> [-0.14305256]</br> [-0.10558325]</br> [-0.09439592]</br> [-0.11793509]</br> [-0.13038892]</br> [-0.14026988]</br> [-0.16070921]</br> [-0.14968147]</br> [-0.1376406 ]</br> [-0.14156808]</br> [-0.18797406]</br> [-0.19658648]</br> [-0.15190131]</br> [-0.17103466]</br> [-0.15 ...

# %% [markdown]
# ### Plot learned kernel

# %%
k_plot_model = m.kern_com.compute_K(x, np.asarray(0.).reshape(-1,1))
plt.figure(figsize=(16, 4))
plt.plot(x, k_plot_model, lw=2)

# %% [markdown]
# ### Compare spectral density of data and learned component kernel

# %%
N = x.size
Yk1 = fft(k_plot_model.reshape(-1,)) #  FFT data
Sk1 =  2./N * np.abs(Yk1[0:N//2]) #  spectral density data

plt.figure(figsize=(16, 8))
plt.subplot(2, 1, 1)
plt.plot(F, S / np.max(np.abs(S)), lw=2)
plt.legend([' Spectral density data'])
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 8000])

plt.subplot(2, 1, 2)
plt.plot(F, S / np.max(np.abs(S)), 'r', lw=2)
plt.plot(F, Sk1 / np.max(np.abs(Sk1)), lw=2)
plt.legend([' Spectral density learned component kernel'])
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 8000])
# Out:
# (0, 8000)

# %%
xkernel = np.linspace(0,3, 48000).reshape(-1, 1)
k_plot_model = m.kern_com.compute_K(xkernel, np.asarray(0.).reshape(-1,1))

plt.figure(figsize=(16, 4))
plt.plot(xkernel, k_plot_model, lw=2)

# %%
tf.reset_default_graph()

# %% [markdown]
# # Example using audio from RWC dataset:
# In this notebook all model paremeters, i.e:  noise variance, lengthscale and variance of activation, all frequencies, variances and lenghscale of component, and variational distributions are learned simultaneously by maximazing the marginal likelihood.

# %%
# %matplotlib inline
import sys 
sys.path.append('../../../../')
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import gpflow, gpitch
reload(gpitch)
from gpitch.amtgp import logistic
from scipy.fftpack import fft, ifft, ifftshift
from scipy import signal
import time
from gpitch import myplots
import soundfile


plt.rcParams['figure.figsize'] = (16, 5)  # set plot size

# %% [markdown]
# ## Import data

# %% [markdown]
# Load and plot data.

# %%
midi = '60'
filename = '../../../../../datasets/rwc/011PFNOM_pitch_' + str(midi) + '.wav'
N = 8000 # number of data points to load
y, fs = soundfile.read(filename, frames=N)
y = y.reshape(-1,1)
x = np.linspace(0, (N-1.)/fs, N).reshape(-1, 1)
plt.figure()
plt.title('data with pitch ' + midi)
plt.plot(x, y, lw=2)

# %% [markdown]
# ## Define model
# We take advantage of the information available in the Fourier transform of the data to initialize the component hyper-parameters, i.e. the frequency of each harmonic and its variance.

# %%
Nc = 10
ideal_f0 = gpitch.amtgp.midi2frec(int(midi))
F_star, S_star, F, Y, S = gpitch.amtgp.init_com_params(y=y, fs=fs, Nh=Nc, ideal_f0=ideal_f0, scaled=True)  # get freqs and var

# %%
plt.figure()
plt.plot(F, S/np.max(S))
plt.plot(F_star, S_star/np.max(S_star), 'xk', mew=2)
plt.legend(['Smoothed spectral density of data', 'location of harmonics found for initialization'])
plt.xlim([0, 8000])
# Out:
# (0, 8000)

# %% [markdown]
# Define kernels for component and activation, and generate model object ("sigmoid model")

# %%
kern_com = gpitch.kernels.MaternSpecMix(input_dim=1, lengthscales=0.1, variances=S_star, 
                                        frequencies=F_star, Nc=Nc)
kern_act = gpflow.kernels.Matern32(input_dim=1, lengthscales=0.1, variance=10.)

# %%
minibatch_size = 200
dec = 160  # samples per window, decimation factor
z = np.vstack((x[::dec].copy(), x[-1].copy()))
m = gpitch.modgp.ModGP(x=x, y=y, z=z, kern_com=kern_com, kern_act=kern_act, whiten=True,
                       minibatch_size=minibatch_size)

# %% [markdown]
# Set all parameters free to optimize, but variances of component

# %%
m.kern_com.fixed = True
m.kern_com.lengthscales.fixed = False
m.kern_com.lengthscales.transform = gpflow.transforms.Logistic(0., 10.0)
m.fixed_msmkern_params(freq=False, var=True)
m.kern_act.fixed = False
m.likelihood.variance.fixed = False
m.z.fixed = True

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern_act.lengthscales</td><td>[ 0.1]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_act.variance</td><td>[ 10.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_1</td><td>[ 248.0620155]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_10</td><td>[ 2506.62665666]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_2</td><td>[ 496.12403101]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_3</td><td>[ 742.18554639]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_4</td><td>[ 990.24756189]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_5</td><td>[ 1240.31007752]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_6</td><td>[ 1490.37259315]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_7</td><td>[ 1740.43510878]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_8</td><td>[ 1994.49862466]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_9</td><td>[ 2248.56214054]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.lengthscales</td><td>[ 0.1]</td><td>None</td><td>[0.0, 10.0]</td></tr><tr><td>model.kern_com.variance_1</td><td>[ 0.12732413]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_10</td><td>[ 0.00338107]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_2</td><td>[ 0.03087981]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_3</td><td>[ 0.01117795]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_4</td><td>[ 0.02145284]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_5</td><td>[ 0.02452587]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_6</td><td>[ 0.00780034]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_7</td><td>[ 0.01048271]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_8</td><td>[ 0.01004723]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_9</td><td>[ 0.00292806]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.likelihood.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.q_mu_act</td><td>[[ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]]</td><td>None</td><td>(none)</td></tr><tr><td>model.q_mu_com</td><td>[[ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]</br> [ 0.]]</td><td>None</td><td>(none)</td></tr><tr><td>model.q_sqrt_act</td><td>[[[ 1.]</br>  [ 0.]</br>  [ 0.]</br>  ..., </br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 1.]</br>  [ 0.]</br>  ..., </br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>  [ 1.]</br>  ..., </br>  [ 0.]</br>  [ 0.]</br>  [ 0.]]</br></br> ..., </br> [[ 0.]</br>  [ 0.]</br>  [ 0.]</br>  ..., </br>  [ 1.]</br>  [ 0.]</br>  [ 0.]]</br></br> [[ 0.]</br>  [ 0.]</br>   ...

# %% [markdown]
# ## Inference

# %%
st = time.time()
logt = []
logx = []
logf = []
def logger(x):
    if (logger.i % 10) == 0:
        logx.append(x)
        logf.append(m._objective(x)[0])
        logt.append(time.time() - st)
    logger.i+=1
logger.i = 1
m.x.minibatch_size = minibatch_size
m.y.minibatch_size = minibatch_size

# %%
maxiter = 2000
m.optimize(method=tf.train.AdamOptimizer(learning_rate=0.01), maxiter=maxiter, 
           callback=logger)
# Out:
#      fun: -31157.531034013733
#      jac: array([ -1.56666913e+04,  -1.59819204e+03,  -2.92101586e+03, ...,
#          1.54475407e-02,   1.69893055e-02,   2.82652213e-01])
#  message: 'Finished iterations.'
#   status: 'Finished iterations.'
#  success: True
#        x: array([ -1.39975636e+00,   1.06191689e+01,   2.46307388e+02, ...,
#          2.53441017e-02,  -2.85880603e-02,   1.57639810e-01])

# %% [markdown]
# List of learned hyperparameters

# %%
plt.plot(-np.array(logf))
plt.xlabel('iteration')
plt.ylabel('ELBO')
# Out:
# Text(0,0.5,u'ELBO')

# %%
mean_f, var_f, mean_g, var_g, x_plot  = m.predict_all(x)

# %%
xlim = [0.0, 0.5]
myplots.plot_results(mean_f, var_f, mean_g, var_g, x_plot, y, z, xlim)

# %%
print('The ideal natural frequency is ' + str(ideal_f0) + 'Hz')
# Out:
# The ideal natural frequency is 261.625565301Hz

# %%
m
#print ideal_f0
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern_act.lengthscales</td><td>[ 0.22046661]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_act.variance</td><td>[ 10.6191943]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_1</td><td>[ 246.30738907]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_10</td><td>[ 2508.77307971]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_2</td><td>[ 493.89560803]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_3</td><td>[ 740.94555155]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_4</td><td>[ 988.80900819]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_5</td><td>[ 1237.84924009]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_6</td><td>[ 1489.51639949]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_7</td><td>[ 1739.59751902]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_8</td><td>[ 1992.93838838]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.frequency_9</td><td>[ 2250.02720391]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern_com.lengthscales</td><td>[ 9.93429038]</td><td>None</td><td>[0.0, 10.0]</td></tr><tr><td>model.kern_com.variance_1</td><td>[ 0.12732413]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_10</td><td>[ 0.00338107]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_2</td><td>[ 0.03087981]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_3</td><td>[ 0.01117795]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_4</td><td>[ 0.02145284]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_5</td><td>[ 0.02452587]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_6</td><td>[ 0.00780034]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_7</td><td>[ 0.01048271]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_8</td><td>[ 0.01004723]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern_com.variance_9</td><td>[ 0.00292806]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.likelihood.variance</td><td>[  2.13837300e-05]</td><td>None</td><td>+ve</td></tr><tr><td>model.q_mu_act</td><td>[[-2.17035386]</br> [ 1.20993385]</br> [ 1.29453743]</br> [ 1.34465352]</br> [ 1.02918596]</br> [ 0.12087289]</br> [-1.08289495]</br> [-1.67961006]</br> [-1.57307209]</br> [-0.82295605]</br> [-0.2034215 ]</br> [ 0.02719865]</br> [ 0.04841216]</br> [-0.05895117]</br> [-0.14191248]</br> [-0.24338139]</br> [-0.29089719]</br> [-0.27434624]</br> [-0.22011472]</br> [-0.17267173]</br> [-0.15335671]</br> [-0.16234742]</br> [-0.17197113]</br> [-0.19925443]</br> [-0.23006589]</br> [-0.2388046 ]</br> [-0.23172039]</br> [-0.22248213]</br> [-0.20819758]</br> [-0.19901237]</br> [-0.20157442]</br> [-0.20881245]</br> [-0.21677484]</br> [-0.23099252]</br> [-0.23684596]</br> [-0.22920148]</br> [-0.22531867]</br> [-0.21952634]</br> [-0.21311696]</br> [-0.205682  ]</br> [-0.20081484]</br> [-0.20734458]</br> [-0.2069175 ]</br> [-0.20941815]</br> [-0.23803569]</br> [-0.22761536]</br> [-0.18609406]</br> [-0.22045038]</br> [-0.22266784]</br> [-0.20351872]</br> [-0.18013759]]</td><td>None</td><td>(none)</td></tr><tr><td>model.q_mu_com</td><td>[[ 6.0904342 ]</br> [-1.51720728]</br> [ 1.22733271]</br> [-1.24198708]</br> [-2.41728272]</br> [ 0.79410303]</br> [-1.74150149]</br> [ 0.07669363]</br> [-1.88003554]</br> [-0.115703  ]</br> [-2.06970793]</br> [-1.04312904]</br> [-1.11066969]</br> [-0.06790462]</br> [-0.62176721]</br> [-0.5680997 ]</br> [ 0.73720769]</br> [-2.71990466]</br> [ 1.24267325]</br> [-1.49741478]</br> [ 0.49734101]</br> [ 1.17387728]</br> [ 1.11967555]</br> [ 1.04485022]</br> [ 2.82440465]</br> [-0.08756766]</br> [ 2.49974799]</br> [ 0.33139592]</br> [ 0.21357433]</br> [ 0.59740302]</br> [-0.4310123 ...

# %% [markdown]
# ### Plot learned kernel

# %%
k_plot_model = m.kern_com.compute_K(x, np.asarray(0.).reshape(-1,1))
plt.figure(figsize=(16, 4))
plt.plot(x, k_plot_model, lw=2)

# %% [markdown]
# ### Compare spectral density of data and learned component kernel

# %%
N = x.size
Yk1 = fft(k_plot_model.reshape(-1,)) #  FFT data
Sk1 =  2./N * np.abs(Yk1[0:N//2]) #  spectral density data

plt.figure(figsize=(16, 8))
plt.subplot(2, 1, 1)
plt.plot(F, S / np.max(np.abs(S)), lw=2)
plt.legend([' Spectral density data'])
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 8000])

plt.subplot(2, 1, 2)
plt.plot(F, S / np.max(np.abs(S)), 'r', lw=2)
plt.plot(F, Sk1 / np.max(np.abs(Sk1)), lw=2)
plt.legend([' Spectral density learned component kernel'])
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 8000])
# Out:
# (0, 8000)

# %%
xkernel = np.linspace(0,3, 48000).reshape(-1, 1)
k_plot_model = m.kern_com.compute_K(xkernel, np.asarray(0.).reshape(-1,1))

plt.figure(figsize=(16, 4))
plt.plot(xkernel, k_plot_model, lw=2)

# %%
tf.reset_default_graph()

# %% [markdown]
# # Load all params learned from MAPS 5 dataset:
# In this notebook all model paremeters, i.e:  noise variance, lengthscale and variance of activation, all frequencies, variances and lenghscale of component, and variational distributions are learned simultaneously by maximazing the marginal likelihood.

# %%
# %matplotlib inline
import sys 
sys.path.append('../../../../')
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import gpflow, gpitch
reload(gpitch)
from gpitch.amtgp import logistic
from scipy.fftpack import fft, ifft, ifftshift
from scipy import signal
import time
from gpitch import myplots
import soundfile
import pickle

plt.rcParams['figure.figsize'] = (16, 3)  # set plot size

# %%
m_60 = pickle.load(open("save_model_maps5_pitch_60.p", "rb"))
m_64 = pickle.load(open("save_model_maps5_pitch_64.p", "rb"))
m_67 = pickle.load(open("save_model_maps5_pitch_67.p", "rb"))
m_72 = pickle.load(open("save_model_maps5_pitch_72.p", "rb"))
m_76 = pickle.load(open("save_model_maps5_pitch_76.p", "rb"))
m_bg = pickle.load(open("save_model_background.p", "rb"))  # model background
models = [m_60, m_64, m_67, m_72, m_76, m_bg]

# %% [markdown]
# ## Import data

# %% [markdown]
# Load and plot data.

# %%
plt.figure(figsize=(16, 18))
plt.title('data')
for i in range(6):
    plt.subplot(6, 1, i+1)
    plt.plot(models[i].x.value, models[i].y.value, lw=2)

# %% [markdown]
# ## Define model
# We take advantage of the information available in the Fourier transform of the data to initialize the component hyper-parameters, i.e. the frequency of each harmonic and its variance.

# %%
fs = 16000.
for i in range(6):
    x = models[i].x.value.copy()
    y = models[i].y.value.copy()
    z = models[i].z.value.copy()
    N = y.size
    mean_f, var_f, mean_g, var_g, x_plot  = models[i].predict_all(x)
    myplots.plot_results(mean_f, var_f, mean_g, var_g, x_plot, y, z, xlim=[0.0, 1.0])

# %%
xkernel = np.linspace(0, 10, 10.*fs).reshape(-1, 1)
F = np.linspace(0, fs//2, N//2).reshape(-1, 1)
plt.figure(1)    
plt.figure(2)

for i in range(6):
    plt.figure(1) 
    plt.plot(-np.array(models[i].logf))
    plt.xlabel('iteration')
    plt.ylabel('ELBO')
    
    plt.figure(2)
    k_plot_model = models[i].kern_com.compute_K(xkernel, np.asarray(0.).reshape(-1,1))
    plt.plot(xkernel, k_plot_model, lw=2)
    
    k_plot_model = models[i].kern_com.compute_K(x, np.asarray(0.).reshape(-1,1))
    Yk1 = fft(k_plot_model.reshape(-1,)) #  FFT data
    Sk1 =  2./N * np.abs(Yk1[0:N//2]) #  spectral density data
    S = np.abs(fft(models[i].y.value.reshape(-1,))[:N//2])
    
    plt.figure()
    plt.plot(F, S / np.max(np.abs(S)), lw=2)
    plt.plot(F, Sk1 / np.max(np.abs(Sk1)), lw=2)
    plt.legend([' Spectral density learned component kernel'])
    plt.xlabel('Frequency (Hz)')
    plt.xlim([0, 8000])
# Out:
# /home/paad/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
#   """Entry point for launching an IPython kernel.

# %%
import tensorflow as tf
kern_com_60 = models[0].kern_com
kern_com_64 = models[1].kern_com
kern_com_67 = models[2].kern_com
kern_com_72 = models[3].kern_com
kern_com_76 = models[4].kern_com

kern_act_60 = models[0].kern_act
kern_act_64 = models[1].kern_act
kern_act_67 = models[2].kern_act
kern_act_72 = models[3].kern_act
kern_act_76 = models[4].kern_act

kern_com_60.fixed = True
kern_com_64.fixed = True
kern_com_67.fixed = True
kern_com_72.fixed = True
kern_com_76.fixed = True

kern_com_bg = models[5].kern_com
kern_act_bg = models[5].kern_act
kern_com_bg.fixed = True

# %%
kern_com_bg
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_com.frequency_1</td><td>[ 261.38687608]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_10</td><td>[ 1312.75224247]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_11</td><td>[ 1578.33418905]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_12</td><td>[ 1647.22496904]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_13</td><td>[ 1845.45920672]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_14</td><td>[ 1980.57856064]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_15</td><td>[ 2111.72484556]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_16</td><td>[ 2649.40900585]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_17</td><td>[ 2775.15425393]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_18</td><td>[ 2932.4679211]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_19</td><td>[ 3196.13310584]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_2</td><td>[ 327.60031959]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_3</td><td>[ 390.95368073]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_4</td><td>[ 523.45588496]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_5</td><td>[ 655.65792867]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_6</td><td>[ 785.3740468]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_7</td><td>[ 983.61369507]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_8</td><td>[ 1048.44490341]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_9</td><td>[ 1175.08492496]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.lengthscales</td><td>[ 1.76314533]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_1</td><td>[ 0.03839539]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_10</td><td>[ 0.00461477]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_11</td><td>[ 0.00589333]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_12</td><td>[ 0.00806637]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_13</td><td>[ 0.01011483]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_14</td><td>[ 0.00390248]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_15</td><td>[ 0.00785408]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_16</td><td>[ 0.00514717]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_17</td><td>[ 0.00164478]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_18</td><td>[ 0.00214104]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_19</td><td>[ 0.00241875]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_2</td><td>[ 0.03479095]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_3</td><td>[ 0.03972852]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_4</td><td>[ 0.02698926]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_5</td><td>[ 0.01731873]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_6</td><td>[ 0.01604142]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_7</td><td>[ 0.00871592]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_8</td><td>[ 0.01392402]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_9</td><td>[ 0.00229818]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
print ('The ideal natural frequency is ' + str(gpitch.amtgp.midi2frec(60)))
# Out:
# The ideal natural frequency is 261.625565301

# %%
kern_com_60
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_com.frequency_1</td><td>[ 261.29457835]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_10</td><td>[ 2658.18417394]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_2</td><td>[ 523.17016131]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_3</td><td>[ 785.07358244]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_4</td><td>[ 1047.92706516]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_5</td><td>[ 1312.55620819]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_6</td><td>[ 1579.15529426]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_7</td><td>[ 1843.92953602]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_8</td><td>[ 2111.34643804]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_9</td><td>[ 2383.32655541]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.lengthscales</td><td>[ 5.74943239]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_1</td><td>[ 0.06879537]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_10</td><td>[ 0.00220377]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_2</td><td>[ 0.03974722]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_3</td><td>[ 0.03583722]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_4</td><td>[ 0.03148765]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_5</td><td>[ 0.01304615]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_6</td><td>[ 0.00665935]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_7</td><td>[ 0.03087762]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_8</td><td>[ 0.01007339]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_9</td><td>[ 0.01127227]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
print ('The ideal natural frequency is ' + str(gpitch.amtgp.midi2frec(64)))
# Out:
# The ideal natural frequency is 329.627556913

# %%
kern_com_64
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_com.frequency_1</td><td>[ 327.58828116]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_10</td><td>[ 3354.3026561]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_2</td><td>[ 655.47379312]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_3</td><td>[ 984.4757668]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_4</td><td>[ 1318.21799374]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_5</td><td>[ 1647.62008095]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_6</td><td>[ 1982.42094037]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_7</td><td>[ 2319.08939197]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_8</td><td>[ 2660.3260517]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_9</td><td>[ 3003.86519232]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.lengthscales</td><td>[ 4.27097075]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_1</td><td>[ 0.09610968]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_10</td><td>[ 0.00217465]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_2</td><td>[ 0.0371303]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_3</td><td>[ 0.01569191]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_4</td><td>[ 0.01333266]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_5</td><td>[ 0.03420266]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_6</td><td>[ 0.01980726]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_7</td><td>[ 0.00876359]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_8</td><td>[ 0.00668124]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_9</td><td>[ 0.01610605]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
print ('The ideal natural frequency is ' + str(gpitch.amtgp.midi2frec(67)))
# Out:
# The ideal natural frequency is 391.995435982

# %%
kern_com_67
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_com.frequency_1</td><td>[ 390.98878131]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_10</td><td>[ 4022.86569902]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_2</td><td>[ 782.64512974]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_3</td><td>[ 1175.59638265]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_4</td><td>[ 1570.59512417]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_5</td><td>[ 1968.38537]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_6</td><td>[ 2371.45496551]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_7</td><td>[ 2778.28367698]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_8</td><td>[ 3186.15481421]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_9</td><td>[ 3601.21264488]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.lengthscales</td><td>[ 4.53101607]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_1</td><td>[ 0.12793362]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_10</td><td>[ 0.00423028]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_2</td><td>[ 0.0470507]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_3</td><td>[ 0.01561644]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_4</td><td>[ 0.01332501]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_5</td><td>[ 0.01269683]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_6</td><td>[ 0.01300995]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_7</td><td>[ 0.00767051]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_8</td><td>[ 0.00173366]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_9</td><td>[ 0.00673301]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
print ('The ideal natural frequency is ' + str(gpitch.amtgp.midi2frec(72)))
# Out:
# The ideal natural frequency is 523.251130601

# %%
kern_com_72
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_com.frequency_1</td><td>[ 523.55798753]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_10</td><td>[ 5485.48166979]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_2</td><td>[ 1047.76810869]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_3</td><td>[ 1576.95488082]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_4</td><td>[ 2109.35697448]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_5</td><td>[ 2649.04117892]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_6</td><td>[ 3196.33148861]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_7</td><td>[ 3753.2677314]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_8</td><td>[ 4315.55102164]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_9</td><td>[ 4894.63886647]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.lengthscales</td><td>[ 7.43236849]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_1</td><td>[ 0.05538776]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_10</td><td>[ 0.00497246]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_2</td><td>[ 0.01067709]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_3</td><td>[ 0.05211655]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_4</td><td>[ 0.04303096]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_5</td><td>[ 0.04721701]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_6</td><td>[ 0.01116374]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_7</td><td>[ 0.01426582]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_8</td><td>[ 0.0090928]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_9</td><td>[ 0.00207581]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
print ('The ideal natural frequency is ' + str(gpitch.amtgp.midi2frec(76)))
# Out:
# The ideal natural frequency is 659.255113826

# %%
kern_com_76
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>kern_com.frequency_1</td><td>[ 656.00112022]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_10</td><td>[ 6278.45462123]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_2</td><td>[ 1314.18463398]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_3</td><td>[ 1976.58585325]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_4</td><td>[ 2648.60904114]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_5</td><td>[ 3331.35730528]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_6</td><td>[ 4028.23070074]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_7</td><td>[ 4737.01191951]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_8</td><td>[ 5464.66814563]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.frequency_9</td><td>[ 6211.53529738]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.lengthscales</td><td>[ 1.77359297]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_1</td><td>[ 0.10690062]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_10</td><td>[ 0.00072118]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_2</td><td>[ 0.01607251]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_3</td><td>[ 0.07789989]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_4</td><td>[ 0.01127439]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_5</td><td>[ 0.02451071]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_6</td><td>[ 0.00669769]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_7</td><td>[ 0.00285909]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_8</td><td>[ 0.00223951]</td><td>None</td><td>[FIXED]</td></tr><tr><td>kern_com.variance_9</td><td>[ 0.00082442]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
testfile = '../../../../../datasets/maps/test_data/segment4-down.wav'
ytest, fs = soundfile.read(testfile, start=0, frames=None)
ytest = ytest.reshape(-1,1)
ytest /= np.max(np.abs(ytest))
Ntest = ytest.size
xtest = np.linspace(0, (Ntest-1.)/fs, Ntest).reshape(-1, 1)

plt.figure()
plt.plot(xtest, ytest)
print Ntest
# Out:
# 32000

# %%
dec = 160
maxiter = 4000
minibatch_size = 200
learning_rate = 0.01
ztest = xtest[::dec].copy()
ztest.shape
# Out:
# (200, 1)

# %%
a, b = 0, Ntest
for i in range(0, 5):
    if i == 0:
        kf = [kern_com_60, kern_com_bg]
        kg = [kern_act_60, kern_act_bg]
        
    if i == 1:
        kf = [kern_com_64, kern_com_bg]
        kg = [kern_act_64, kern_act_bg]
        
    if i == 2:
        kf = [kern_com_67, kern_com_bg]
        kg = [kern_act_67, kern_act_bg]
              
    if i == 3:
        kf = [kern_com_72, kern_com_bg]
        kg = [kern_act_72, kern_act_bg]  
              
    if i == 4:
        kf = [kern_com_76, kern_com_bg]
        kg = [kern_act_76, kern_act_bg] 
              
    m = gpitch.loogp.LooGP(X=xtest, Y=ytest, kf=kf, kg=kg, Z=ztest, minibatch_size=minibatch_size)
    m.optimize_svi(maxiter=maxiter, learning_rate=learning_rate)
    mean_f, var_f, mean_g, var_g = m.predict_all(xtest[a:b])

    plt.figure()
    plt.plot(-np.array(m.logf))
    plt.xlabel('iteration')
    plt.ylabel('ELBO')

    gpitch.myplots.plot_loo(mean_f=mean_f, var_f=var_f, mean_g=mean_g, var_g=var_g, 
                            x_plot=xtest[a:b], y=ytest[a:b], z=m.Z.value, xlim=None)

    tf.reset_default_graph()
